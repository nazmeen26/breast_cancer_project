# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("Breast Cancer METABRIC_final.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3344 entries, 0 to 3343
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   AgeatDiagnosis                  3344 non-null   float64
#  1   TypeofBreastSurgery             3344 non-null   int64
#  2   CancerType                      3344 non-null   int64
#  3   Cellularity                     3344 non-null   int64
#  4   Chemotherapy                    3344 non-null   int64
#  5   Cohort                          3344 non-null   float64
#  6   ERstatusmeasuredbyIHC           3344 non-null   int64
#  7   ERStatus                        3344 non-null   int64
#  8   NeoplasmHistologicGrade         3344 non-null   float64
#  9   HER2statusmeasuredbySNP6        3344 non-null   int64
#  10  HER2Status                      3344 non-null   int64
#  11  HormoneTherapy                  3344 non-null   int64
# ...

# %%
df.shape
# Out:
# (3344, 32)

# %%
df.columns
# Out:
# Index(['AgeatDiagnosis', 'TypeofBreastSurgery', 'CancerType', 'Cellularity',
#        'Chemotherapy', 'Cohort', 'ERstatusmeasuredbyIHC', 'ERStatus',
#        'NeoplasmHistologicGrade', 'HER2statusmeasuredbySNP6', 'HER2Status',
#        'HormoneTherapy', 'InferredMenopausalState', 'PrimaryTumorLaterality',
#        'Lymphnodesexaminedpositive', 'MutationCount',
#        'Nottinghamprognosticindex', 'OverallSurvival_Months',
#        'OverallSurvivalStatus', 'PRStatus', 'RadioTherapy',
#        'RelapseFreeStatus_Months', 'RelapseFreeStatus',
#        'Geneclassifiersubtype', 'TumorSize', 'TumorStage',
#        'PatientsVitalStatus', 'Cancer_Type_Detailed', 'CPam50low_subtype',
#        'Tumor_Other_Histologic_Subtype', 'Integrative_Cluster',
#        'Oncotree_Code'],
#       dtype='object')

# %%
df.head()
# Out:
#    AgeatDiagnosis  TypeofBreastSurgery  CancerType  Cellularity  Chemotherapy  \
# 0           48.87                    1           1            1             0
# 1           76.97                    1           1            1             0
# 2           78.77                    1           1            2             1
# 3           70.00                    1           1            1             0
# 4           89.08                    0           1            2             1
#
#    Cohort  ERstatusmeasuredbyIHC  ERStatus  NeoplasmHistologicGrade  \
# 0     1.0                      1         1                      2.0
# 1     1.0                      1         1                      3.0
# 2     1.0                      1         1                      3.0
# 3     1.0                      0         0                      3.0
# 4     1.0                      1         1                      2.0
#
#    HER2statusmeasuredbySNP6  ...  RelapseFreeStatus  Geneclassifiersubtype  \
# ...

# %%
df['OverallSurvivalStatus'].value_counts()
# Out:
# OverallSurvivalStatus
# 1    1672
# 0    1672
# Name: count, dtype: int64

# %%
df[df['AgeatDiagnosis']==0]
# Out:
# Empty DataFrame
# Columns: [AgeatDiagnosis, TypeofBreastSurgery, CancerType, Cellularity, Chemotherapy, Cohort, ERstatusmeasuredbyIHC, ERStatus, NeoplasmHistologicGrade, HER2statusmeasuredbySNP6, HER2Status, HormoneTherapy, InferredMenopausalState, PrimaryTumorLaterality, Lymphnodesexaminedpositive, MutationCount, Nottinghamprognosticindex, OverallSurvival_Months, OverallSurvivalStatus, PRStatus, RadioTherapy, RelapseFreeStatus_Months, RelapseFreeStatus, Geneclassifiersubtype, TumorSize, TumorStage, PatientsVitalStatus, Cancer_Type_Detailed, CPam50low_subtype, Tumor_Other_Histologic_Subtype, Integrative_Cluster, Oncotree_Code]
# Index: []
#
# [0 rows x 32 columns]

# %%
df[df['TypeofBreastSurgery']==0]
# Out:
#       AgeatDiagnosis  TypeofBreastSurgery  CancerType  Cellularity  \
# 4              89.08                    0           1            2
# 6              86.41                    0           1            2
# 12             64.85                    0           1            2
# 14             51.58                    0           1            2
# 17             43.15                    0           1            0
# ...              ...                  ...         ...          ...
# 3332           50.92                    0           1            2
# 3334           43.39                    0           1            1
# 3337           55.67                    0           1            1
# 3339           64.10                    0           1            2
# 3343           57.33                    0           1            0
#
#       Chemotherapy  Cohort  ERstatusmeasuredbyIHC  ERStatus  \
# 4                1     1.0                      1         1
# ...

# %%
df[df['CancerType']==0]
# Out:
#       AgeatDiagnosis  TypeofBreastSurgery  CancerType  Cellularity  \
# 1851           58.96                    0           0            1
# 1901           52.79                    1           0            1
# 1911           52.79                    1           0            1
# 1916           52.79                    1           0            1
# 1989           58.96                    0           0            1
# 2253           58.96                    0           0            1
# 2285           51.42                    1           0            2
# 2812           52.79                    1           0            1
# 3078           52.79                    1           0            1
# 3175           51.42                    1           0            2
# 3245           52.79                    1           0            1
#
#       Chemotherapy  Cohort  ERstatusmeasuredbyIHC  ERStatus  \
# 1851             1     1.0                      1         0
# ...

# %%
df[df['Cellularity']==0]
# Out:
#       AgeatDiagnosis  TypeofBreastSurgery  CancerType  Cellularity  \
# 15             68.68                    1           1            0
# 17             43.15                    0           1            0
# 24             63.53                    1           1            0
# 31             77.13                    0           1            0
# 36             79.28                    0           1            0
# ...              ...                  ...         ...          ...
# 3280           42.68                    0           1            0
# 3282           38.92                    0           1            0
# 3288           57.33                    0           1            0
# 3311           60.50                    1           1            0
# 3343           57.33                    0           1            0
#
#       Chemotherapy  Cohort  ERstatusmeasuredbyIHC  ERStatus  \
# 15               0     1.0                      0         0
# ...

# %%
df[df['Chemotherapy']==0]
# Out:
#       AgeatDiagnosis  TypeofBreastSurgery  CancerType  Cellularity  \
# 0              48.87                    1           1            1
# 1              76.97                    1           1            1
# 3              70.00                    1           1            1
# 11             50.42                    1           1            1
# 14             51.58                    0           1            2
# ...              ...                  ...         ...          ...
# 3318           38.72                    0           1            1
# 3322           62.97                    0           1            1
# 3328           60.89                    0           1            1
# 3334           43.39                    0           1            1
# 3341           37.30                    1           1            2
#
#       Chemotherapy  Cohort  ERstatusmeasuredbyIHC  ERStatus  \
# 0                0     1.0                      1         1
# ...

# %%
df['TypeofBreastSurgery'] = df['TypeofBreastSurgery'].replace(0,df['TypeofBreastSurgery'].mean())
df['CancerType'] = df['CancerType'].replace(0,df['CancerType'].mean())
df['Cellularity'] = df['Cellularity'].replace(0,df['Cellularity'].mean())
df['Chemotherapy'] = df['Chemotherapy'].replace(0,df['Chemotherapy'].mean())
df['Cohort'] = df['Cohort'].replace(0,df['Cohort'].mean())
df['ERstatusmeasuredbyIHC'] = df['ERstatusmeasuredbyIHC'].replace(0,df['ERstatusmeasuredbyIHC'].mean())
df['ERStatus'] = df['ERStatus'].replace(0,df['ERStatus'].mean())
df['NeoplasmHistologicGrade'] = df['NeoplasmHistologicGrade'].replace(0,df['NeoplasmHistologicGrade'].mean())
df['HER2statusmeasuredbySNP6'] = df['HER2statusmeasuredbySNP6'].replace(0,df['HER2statusmeasuredbySNP6'].mean())
df['HER2Status'] = df['HER2Status'].replace(0,df['HER2Status'].mean())
df['HormoneTherapy'] = df['HormoneTherapy'].replace(0,df['HormoneTherapy'].mean())
df['PrimaryTumorLaterality'] = df['PrimaryTumorLaterality'].replace(0,df['PrimaryTumorLaterality'].mean())
df['Lymphnodesexaminedpositive'] = df['Lymphnodesexaminedpositive'].replace(0,df['Lymphnodesexaminedpositive'].mean())
df['MutationCount'] = df['MutationCount'].replace(0,df['MutationCount'].mean())
df['Nottinghamprognosticindex'] = df['Nottinghamprognosticindex'].replace(0,df['Nottinghamprognosticindex'].mean())
df['OverallSurvival_Months'] = df['OverallSurvival_Months'].replace(0,df['OverallSurvival_Months'].mean())

df['PRStatus'] = df['PRStatus'].replace(0,df['PRStatus'].mean())
df['RadioTherapy'] = df['RadioTherapy'].replace(0,df['RadioTherapy'].mean())
df['RelapseFreeStatus_Months'] = df['RelapseFreeStatus_Months'].replace(0,df['RelapseFreeStatus_Months'].mean())
df['RelapseFreeStatus'] = df['RelapseFreeStatus'].replace(0,df['RelapseFreeStatus'].mean())

df['Geneclassifiersubtype'] = df['Geneclassifiersubtype'].replace(0,df['Geneclassifiersubtype'].mean())
df['TumorSize'] = df['TumorSize'].replace(0,df['TumorSize'].mean())

df['PatientsVitalStatus'] = df['PatientsVitalStatus'].replace(0,df['PatientsVitalStatus'].mean())
df['Cancer_Type_Detailed'] = df['Cancer_Type_Detailed'].replace(0,df['Cancer_Type_Detailed'].mean())
df['CPam50low_subtype'] = df['CPam50low_subtype'].replace(0,df['CPam50low_subtype'].mean())
df['Tumor_Other_Histologic_Subtype'] = df['Tumor_Other_Histologic_Subtype'].replace(0,df['Tumor_Other_Histologic_Subtype'].mean())
df['Integrative_Cluster'] = df['Integrative_Cluster'].replace(0,df['Integrative_Cluster'].mean())
df['Oncotree_Code'] = df['Oncotree_Code'].replace(0,df['Oncotree_Code'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3344 entries, 0 to 3343
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   AgeatDiagnosis                  3344 non-null   float64
#  1   TypeofBreastSurgery             3344 non-null   float64
#  2   CancerType                      3344 non-null   float64
#  3   Cellularity                     3344 non-null   float64
#  4   Chemotherapy                    3344 non-null   float64
#  5   Cohort                          3344 non-null   float64
#  6   ERstatusmeasuredbyIHC           3344 non-null   float64
#  7   ERStatus                        3344 non-null   float64
#  8   NeoplasmHistologicGrade         3344 non-null   float64
#  9   HER2statusmeasuredbySNP6        3344 non-null   float64
#  10  HER2Status                      3344 non-null   float64
#  11  HormoneTherapy                  3344 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['AgeatDiagnosis', 'TypeofBreastSurgery', 'CancerType', 'Cellularity',
#        'Chemotherapy', 'Cohort', 'ERstatusmeasuredbyIHC', 'ERStatus',
#        'NeoplasmHistologicGrade', 'HER2statusmeasuredbySNP6', 'HER2Status',
#        'HormoneTherapy', 'InferredMenopausalState', 'PrimaryTumorLaterality',
#        'Lymphnodesexaminedpositive', 'MutationCount',
#        'Nottinghamprognosticindex', 'OverallSurvival_Months',
#        'OverallSurvivalStatus', 'PRStatus', 'RadioTherapy',
#        'RelapseFreeStatus_Months', 'RelapseFreeStatus',
#        'Geneclassifiersubtype', 'TumorSize', 'TumorStage',
#        'PatientsVitalStatus', 'Cancer_Type_Detailed', 'CPam50low_subtype',
#        'Tumor_Other_Histologic_Subtype', 'Integrative_Cluster',
#        'Oncotree_Code'],
#       dtype='object')

# %%
X=df.drop('OverallSurvivalStatus', axis=1)
y=df['OverallSurvivalStatus']

# %%
X
# Out:
#       AgeatDiagnosis  TypeofBreastSurgery  CancerType  Cellularity  \
# 0              48.87             1.000000         1.0      1.00000
# 1              76.97             1.000000         1.0      1.00000
# 2              78.77             1.000000         1.0      2.00000
# 3              70.00             1.000000         1.0      1.00000
# 4              89.08             0.645634         1.0      2.00000
# ...              ...                  ...         ...          ...
# 3339           64.10             0.645634         1.0      2.00000
# 3340           77.13             1.000000         1.0      1.00000
# 3341           37.30             1.000000         1.0      2.00000
# 3342           57.27             1.000000         1.0      1.00000
# 3343           57.33             0.645634         1.0      1.21561
#
#       Chemotherapy  Cohort  ERstatusmeasuredbyIHC  ERStatus  \
# 0          0.82177     1.0               1.000000  1.000000
# ...

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 3339    0
# 3340    0
# 3341    0
# 3342    0
# 3343    0
# Name: OverallSurvivalStatus, Length: 3344, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((2508, 31), (836, 31))

# %%
X_train.corr()
# Out:
#                                 AgeatDiagnosis  TypeofBreastSurgery  \
# AgeatDiagnosis                        1.000000             0.078672
# TypeofBreastSurgery                   0.078672             1.000000
# CancerType                            0.023319            -0.002651
# Cellularity                           0.043449            -0.066870
# Chemotherapy                          0.346420             0.027718
# Cohort                               -0.014800             0.120848
# ERstatusmeasuredbyIHC                 0.270511            -0.031365
# ERStatus                              0.240265            -0.009214
# NeoplasmHistologicGrade              -0.093870             0.033311
# HER2statusmeasuredbySNP6              0.035567            -0.098891
# HER2Status                            0.082695            -0.029559
# HormoneTherapy                        0.212170             0.087877
# InferredMenopausalState               0.650146             0.089899
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
    #scaling the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
import pickle
file_path = r'D:\Data Science\breastcancer_project\models\standardscalar.pkl'
with open(file_path, 'wb') as file:
    pickle.dump(scaler, file)

# %%
X_train_scaled
# Out:
# array([[-1.55833005,  0.74101578,  0.060012  , ..., -0.0092646 ,
#          0.02186088, -0.23907839],
#        [-0.94775638, -1.34949893,  0.060012  , ..., -0.0092646 ,
#          0.14225924, -0.23907839],
#        [-0.18991266,  0.74101578,  0.060012  , ...,  1.06536981,
#          0.02186088,  0.88435908],
#        ...,
#        [-0.76386783,  0.74101578,  0.060012  , ..., -0.0092646 ,
#          0.02186088, -0.23907839],
#        [ 1.55503841, -1.34949893,  0.060012  , ..., -0.0092646 ,
#         -1.05167441, -0.23907839],
#        [-1.81227138,  0.74101578,  0.060012  , ..., -0.0092646 ,
#         -0.65369653, -0.23907839]], shape=(2508, 31))

# %%
# !pip install xgboost

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report,ConfusionMatrixDisplay, \
                            precision_score, recall_score, f1_score, roc_auc_score,roc_curve

# %%
models={
    "Logisitic_Regression":LogisticRegression(),
    "Decision_Tree":DecisionTreeClassifier(),
    "Random_Forest":RandomForestClassifier(),
    "Gradient_Boost":GradientBoostingClassifier(),
    "Adaboost":AdaBoostClassifier(),
    "Xgboost":XGBClassifier()
}
for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train, y_train) # Train model

    # Make predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # Training set performance
    model_train_accuracy = accuracy_score(y_train, y_train_pred) # Calculate Accuracy
    model_train_f1 = f1_score(y_train, y_train_pred, average='weighted') # Calculate F1-score
    model_train_precision = precision_score(y_train, y_train_pred) # Calculate Precision
    model_train_recall = recall_score(y_train, y_train_pred) # Calculate Recall
    model_train_rocauc_score = roc_auc_score(y_train, y_train_pred)


# Test set performance
    model_test_accuracy = accuracy_score(y_test, y_test_pred) # Calculate Accuracy
    model_test_f1 = f1_score(y_test, y_test_pred, average='weighted') # Calculate F1-score
    model_test_precision = precision_score(y_test, y_test_pred) # Calculate Precision
    model_test_recall = recall_score(y_test, y_test_pred) # Calculate Recall
    model_test_rocauc_score = roc_auc_score(y_test, y_test_pred) #Calculate Roc


    print(list(models.keys())[i])
    
    print('Model performance for Training set')
    print("- Accuracy: {:.4f}".format(model_train_accuracy))
    print('- F1 score: {:.4f}'.format(model_train_f1))
    
    print('- Precision: {:.4f}'.format(model_train_precision))
    print('- Recall: {:.4f}'.format(model_train_recall))
    print('- Roc Auc Score: {:.4f}'.format(model_train_rocauc_score))

    
    
    print('----------------------------------')
    
    print('Model performance for Test set')
    print('- Accuracy: {:.4f}'.format(model_test_accuracy))
    print('- F1 score: {:.4f}'.format(model_test_f1))
    print('- Precision: {:.4f}'.format(model_test_precision))
    print('- Recall: {:.4f}'.format(model_test_recall))
    print('- Roc Auc Score: {:.4f}'.format(model_test_rocauc_score))


    print('='*35)
    print('\n')
# Out:
# Logisitic_Regression
# Model performance for Training set
# - Accuracy: 0.8190
# - F1 score: 0.8190
# - Precision: 0.8144
# - Recall: 0.8117
# - Roc Auc Score: 0.8188
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.8170
# - F1 score: 0.8172
# - Precision: 0.8451
# - Recall: 0.8136
# - Roc Auc Score: 0.8173
# ...
#
#
# Decision_Tree
# Model performance for Training set
# - Accuracy: 1.0000
# - F1 score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 1.0000
# - F1 score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# ...
# d:\Data Science\breastcancer_project\venv\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
# ...

# %%
Random_Forest=RandomForestClassifier()
Random_Forest.fit(X_train_scaled,y_train)
# Out:
# RandomForestClassifier()

# %%
Random_Forest
# Out:
# RandomForestClassifier()

# %%
## Hyperparameter Training
rf_params = {"max_depth": [5, 8, 15, None, 10],
             "max_features": [5, 7, "auto", 8],
             "min_samples_split": [2, 8, 15, 20],
             "n_estimators": [100, 200, 500, 1000]}
xgboost_params = {"learning_rate": [0.1, 0.01],
                  "max_depth": [5, 8, 12, 20, 30],
                  "n_estimators": [100, 200, 300],
                  "colsample_bytree": [0.5, 0.8, 1, 0.3, 0.4]}

# %%
# Models list for Hyperparameter tuning
randomcv_models = [
                   ("RF", RandomForestClassifier(), rf_params)
                   
                   ]

# %%
randomcv_models
# Out:
# [('RF',
#   RandomForestClassifier(),
#   {'max_depth': [5, 8, 15, None, 10],
#    'max_features': [5, 7, 'auto', 8],
#    'min_samples_split': [2, 8, 15, 20],
#    'n_estimators': [100, 200, 500, 1000]})]

# %%
from sklearn.model_selection import RandomizedSearchCV

model_param = {}
for name, model, params in randomcv_models:
    random = RandomizedSearchCV(estimator=model,
                                   param_distributions=params,
                                   n_iter=100,
                                   cv=3,
                                   verbose=2,
                                   n_jobs=-1)
    random.fit(X_train, y_train)
    model_param[name] = random.best_params_

for model_name in model_param:
    print(f"---------------- Best Params for {model_name} -------------------")
    print(model_param[model_name])
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# d:\Data Science\breastcancer_project\venv\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 87 fits failed out of a total of 300.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 28 fits failed with the following error:
# Traceback (most recent call last):
#   File "d:\Data Science\breastcancer_project\venv\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "d:\Data Science\breastcancer_project\venv\Lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
# ...

# %%
models={
    
    "Random_Forest":RandomForestClassifier(n_estimators=500,min_samples_split=2,
                                          max_features=7,max_depth=8)
}
for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train, y_train) # Train model

    # Make predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # Training set performance
    model_train_accuracy = accuracy_score(y_train, y_train_pred) # Calculate Accuracy
    model_train_f1 = f1_score(y_train, y_train_pred, average='weighted') # Calculate F1-score
    model_train_precision = precision_score(y_train, y_train_pred) # Calculate Precision
    model_train_recall = recall_score(y_train, y_train_pred) # Calculate Recall
    model_train_rocauc_score = roc_auc_score(y_train, y_train_pred)


    # Test set performance
    model_test_accuracy = accuracy_score(y_test, y_test_pred) # Calculate Accuracy
    model_test_f1 = f1_score(y_test, y_test_pred, average='weighted') # Calculate F1-score
    model_test_precision = precision_score(y_test, y_test_pred) # Calculate Precision
    model_test_recall = recall_score(y_test, y_test_pred) # Calculate Recall
    model_test_rocauc_score = roc_auc_score(y_test, y_test_pred) #Calculate Roc


    print(list(models.keys())[i])
    
    print('Model performance for Training set')
    print("- Accuracy: {:.4f}".format(model_train_accuracy))
    print('- F1 score: {:.4f}'.format(model_train_f1))
    
    print('- Precision: {:.4f}'.format(model_train_precision))
    print('- Recall: {:.4f}'.format(model_train_recall))
    print('- Roc Auc Score: {:.4f}'.format(model_train_rocauc_score))

    
    
    print('----------------------------------')
    
    print('Model performance for Test set')
    print('- Accuracy: {:.4f}'.format(model_test_accuracy))
    print('- F1 score: {:.4f}'.format(model_test_f1))
    print('- Precision: {:.4f}'.format(model_test_precision))
    print('- Recall: {:.4f}'.format(model_test_recall))
    print('- Roc Auc Score: {:.4f}'.format(model_test_rocauc_score))

    
    print('='*35)
    print('\n')
# Out:
# Random_Forest
# Model performance for Training set
# - Accuracy: 0.9996
# - F1 score: 0.9996
# - Precision: 1.0000
# - Recall: 0.9992
# - Roc Auc Score: 0.9996
# ----------------------------------
# Model performance for Test set
# - Accuracy: 1.0000
# - F1 score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# ...

# %%
df.columns
# Out:
# Index(['AgeatDiagnosis', 'TypeofBreastSurgery', 'CancerType', 'Cellularity',
#        'Chemotherapy', 'Cohort', 'ERstatusmeasuredbyIHC', 'ERStatus',
#        'NeoplasmHistologicGrade', 'HER2statusmeasuredbySNP6', 'HER2Status',
#        'HormoneTherapy', 'InferredMenopausalState', 'PrimaryTumorLaterality',
#        'Lymphnodesexaminedpositive', 'MutationCount',
#        'Nottinghamprognosticindex', 'OverallSurvival_Months',
#        'OverallSurvivalStatus', 'PRStatus', 'RadioTherapy',
#        'RelapseFreeStatus_Months', 'RelapseFreeStatus',
#        'Geneclassifiersubtype', 'TumorSize', 'TumorStage',
#        'PatientsVitalStatus', 'Cancer_Type_Detailed', 'CPam50low_subtype',
#        'Tumor_Other_Histologic_Subtype', 'Integrative_Cluster',
#        'Oncotree_Code'],
#       dtype='object')

# %%
file_path = r'D:\Data Science\breastcancer_project\models\randomf.pkl'
with open(file_path, 'wb') as file:
    pickle.dump(Random_Forest, file)
